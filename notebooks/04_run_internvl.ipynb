# %% [markdown]
# # 04 - Run Inference: InternVL3
#
# Generates radiology reports using InternVL3 and writes `outputs/predictions/internvl3_predictions.csv`.
#
# **Kaggle GPU:** enable a GPU accelerator before running this notebook.

# %%
# !pip install -q -U transformers accelerate timm einops

# %%
import sys
sys.path.insert(0, '/kaggle/working/medical-report-benchmark')
# %cd /kaggle/working/medical-report-benchmark

# %%
# Quick debug run first (5 samples)
# !python -m inference.generate_reports --model internvl3 --max-samples 5

# %%
import pandas as pd
preview = pd.read_csv('outputs/predictions/internvl3_predictions.csv')
preview.head()

# %%
# Full run over the configured dataset split.
# !python -m inference.generate_reports --model internvl3
