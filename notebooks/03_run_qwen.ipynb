# %% [markdown]
# # 03 - Run Inference: Qwen2.5-VL
#
# Generates radiology reports using Qwen2.5-VL and writes `outputs/predictions/qwen25_vl_predictions.csv`.
#
# **Kaggle GPU:** enable a GPU accelerator (Settings -> Accelerator -> GPU T4 x2 or better) before running this notebook.

# %%
# !pip install -q -U transformers accelerate qwen-vl-utils

# %%
import sys
sys.path.insert(0, '/kaggle/working/medical-report-benchmark')
# %cd /kaggle/working/medical-report-benchmark

# %%
# Quick debug run first (5 samples) to confirm everything works end to end
# !python -m inference.generate_reports --model qwen25_vl --max-samples 5

# %%
import pandas as pd
preview = pd.read_csv('outputs/predictions/qwen25_vl_predictions.csv')
preview.head()

# %%
# Full run over the configured dataset split. Remove --max-samples for the full run;
# the script resumes automatically (config.inference.resume=true) if interrupted.
# !python -m inference.generate_reports --model qwen25_vl
