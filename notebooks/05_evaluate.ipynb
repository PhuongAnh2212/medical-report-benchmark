# %% [markdown]
# # 05 - Evaluate Predictions
#
# Computes BLEU-1..4, ROUGE-L, METEOR, and CIDEr for every `outputs/predictions/*_predictions.csv` file and writes one `results/<model>_results.csv` per model.

# %%
# !pip install -q nltk rouge-score pycocoevalcap

# %%
import sys
sys.path.insert(0, '/kaggle/working/medical-report-benchmark')
# %cd /kaggle/working/medical-report-benchmark

# %%
# !python -m evaluation.evaluate

# %%
import pandas as pd, glob
for f in sorted(glob.glob('results/*_results.csv')):
    print(f)
    display(pd.read_csv(f))
